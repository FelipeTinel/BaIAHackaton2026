# %%
import pandas as pd
import os

# Testes e conclusões com o dataset

data_base = os.path.join('..', 'data', 'clima_bahia_hackathon(1).csv')

db = pd.read_csv(data_base)

db.describe()
# Out:
#          HORA (UTC)  PRECIPITACAO TOTAL HORARIO (mm)  \
# count  5.206752e+06                     5.036677e+06
# mean   1.150000e+03                    -9.657275e+02
# std    6.922187e+02                     2.953745e+03
# min    0.000000e+00                    -9.999000e+03
# 25%    5.750000e+02                     0.000000e+00
# 50%    1.150000e+03                     0.000000e+00
# 75%    1.725000e+03                     0.000000e+00
# max    2.300000e+03                     8.520000e+01
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# count                                       5.109466e+06
# mean                                        1.970921e+02
# std                                         2.810523e+03
# min                                        -9.999000e+03
# 25%                                         9.520000e+02
# 50%                                         9.669000e+02
# 75%                                         9.932000e+02
# ...

# %%
df_a401 = db[(db['ESTACAO'] == 'A401') & (db['PRECIPITACAO TOTAL HORARIO (mm)'] > 10)]
print(df_a401[['DATA (YYYY-MM-DD)', 'PRECIPITACAO TOTAL HORARIO (mm)']].dropna().drop_duplicates(subset=['DATA (YYYY-MM-DD)']).head(5))
# Out:
#       DATA (YYYY-MM-DD)  PRECIPITACAO TOTAL HORARIO (mm)
# 182          2021-01-08                             25.8
# 275          2021-01-12                             29.6
# 343          2021-01-15                             27.2
# 34987        2020-01-01                             10.2
# 35487        2020-01-22                             15.0

# %%
print(db_a401[['DATA (YYYY-MM-DD)', 'PRECIPITACAO TOTAL HORARIO (mm)']].dropna().drop_duplicates(subset=['DATA (YYYY-MM-DD)']).head(5))
# Out:
#       DATA (YYYY-MM-DD)  PRECIPITACAO TOTAL HORARIO (mm)
# 182          2021-01-08                             25.8
# 275          2021-01-12                             29.6
# 343          2021-01-15                             27.2
# 344          2021-01-15                             31.2
# 5556         2021-01-15                             22.8
# 5559         2021-01-15                             30.8
# 13666        2021-01-12                             29.8
# 16650        2021-01-12                             24.2
# 16669        2021-01-13                             30.6
# 21571        2021-01-31                             27.8
